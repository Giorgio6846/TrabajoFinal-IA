# %%
from Blackjack.Environment import BJEnvironment

# %%
env = BJEnvironment()

# %%
for _ in range(1000):
    env.reset(5)
    print(env.get_obs())
# Out:
# [[18  5  0  0  1  1  0]]
# [[13  7  0  0  1  3  0]]
# [[15 10  0  0  1  2  0]]
# [[12 10  0  0  1  4  0]]
# [[20  4  0  0  1  0  0]]
# [[13  7  0  0  1  3  0]]
# [[7 9 0 0 1 6 0]]
# [[14 10  0  0  1  3  0]]
# [[9 6 0 0 1 5 0]]
# [[21  2  0  0  1  0  0]]
# [[20  7  0  1  1  0  0]]
# [[13  5  0  0  1  3  0]]
# [[18 10  0  0  1  1  0]]
# [[12  2  0  1  1  4  0]]
# [[10  6  0  0  1  5  0]]
# [[14 10  0  0  1  3  0]]
# [[9 4 0 0 1 5 0]]
# [[13 10  0  0  1  3  0]]
# [[19 10  0  0  1  0  0]]
# [[13  3  0  0  1  3  0]]
# [[17  4  0  0  1  1  0]]
# [[14 10  0  0  1  3  0]]
# [[11  2  0  0  1  4  0]]
# [[20  8  0  0  1  0  0]]
# [[20 11  0  0  1  0  0]]
# [[16  9  0  0  1  2  0]]
# [[14 10  0  0  1  3  0]]
# [[19 10  0  0  1  0  0]]
# [[13 10  0  0  1  3  0]]
# [[19 10  0  0  1  0  0]]
# [[12 10  0  0  1  4  0]]
# [[12 10  0  0  1  4  0]]
# [[13  5  0  0  1  3  0]]
# [[10 11  0  0  1  5  0]]
# [[15 10  0  0  1  2  0]]
# [[14 10  0  0  1  3  0]]
# [[15  5  0  0  1  2  0]]
# ...

# %%
env.reset(5)

print(env.get_obs()[0])
# Out:
# [20  3  0  1  1  0  0]

# %%
env.reset(5)

obs = env.get_obs()
obs
# Out:
# array([[15,  5,  0,  0,  1,  2,  0]], dtype=uint8)

# %%
state, action, reward, next_state, done = env.step(0)
next_state
# Out:
# Dealer hits and has: 4♥ J♠ A♣ 15
# Dealer hits and has: 4♥ J♠ A♣ J♥ 25
# loss
# array([[25, 25,  0,  0,  0,  0,  0]], dtype=uint8)

# %%
print(reward)
# Out:
# 1

# %%
state, action, reward, next_state, done = env.step(1)
print(next_state)
print(reward)
# Out:
# win
# [[21 20  0  0  0  0  0]]
# 2
