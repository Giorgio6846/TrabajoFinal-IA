# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./testModels.csv")
df.head()
# Out:
#    learningRate  gamma  epsilonMin  epsilon  batchSize  annelingSteps  \
# 0          0.19   0.91        0.15     0.97         24           6500
# 1          0.07   0.94        0.17     0.96         32           6000
# 2          0.01   0.91        0.16     0.92          8          13500
# 3          0.06   0.98        0.16     0.86         24           9500
# 4          0.16   0.88        0.19     0.90         32          13500
#
#    VERSION  COMVER   mean
# 0        1       1  36.76
# 1        2       1  30.15
# 2        3       1  29.12
# 3        4       1  20.58
# 4        5       1  29.09

# %%
df.corr()
# Out:
#                learningRate     gamma  epsilonMin   epsilon  batchSize  \
# learningRate       1.000000 -0.136188   -0.115954  0.326747   0.058089
# gamma             -0.136188  1.000000    0.134963  0.062445  -0.058417
# epsilonMin        -0.115954  0.134963    1.000000 -0.350374  -0.084870
# epsilon            0.326747  0.062445   -0.350374  1.000000   0.260656
# batchSize          0.058089 -0.058417   -0.084870  0.260656   1.000000
# annelingSteps     -0.444854 -0.114768    0.348013 -0.242751   0.243343
# VERSION            0.018443  0.073598   -0.112272 -0.247292  -0.391463
# COMVER                  NaN       NaN         NaN       NaN        NaN
# mean               0.525842 -0.326097   -0.146977  0.713292  -0.047822
#
#                annelingSteps   VERSION  COMVER      mean
# learningRate       -0.444854  0.018443     NaN  0.525842
# gamma              -0.114768  0.073598     NaN -0.326097
# epsilonMin          0.348013 -0.112272     NaN -0.146977
# ...

# %%
columns = [
    "learningRate",
    "gamma",
    "epsilonMin",
    "epsilon",
    "batchSize",
    "annelingSteps",
    "mean",
]
df[columns].corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_391a2_row0_col0, #T_391a2_row1_col1, #T_391a2_row2_col2, #T_391a2_row3_col3, #T_391a2_row4_col4, #T_391a2_row5_col5, #T_391a2_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_391a2_row0_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_391a2_row0_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_391a2_row0_col3 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_391a2_row0_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_391a2_row0_col5, #T_391a2_row1_col6, #T_391a2_row2_col3, #T_391a2_row2_col4, #T_391a2_row3_col2, #T_391a2_row5_col0, #T_391a2_row6_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_391a2_row0_col6 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_391a2_row1_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_391a2_row1_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_391a2_row1_col3 {
# ...

# %%
sns.pairplot(df[columns])
