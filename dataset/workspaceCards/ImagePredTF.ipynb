# %%
import tensorflow as tf
import numpy as np
from PIL import Image

# %%
Model = tf.saved_model.load("./dataset/workspaceCards/YoloModel/v3/weights/last_saved_model/")

# %%
Model = tf.saved_model.load("YoloModel/v3/weights/last_saved_model/")

# %%
Model.signatures
# Out:
# _SignatureMap({})

# %%
img_width, img_height = 640, 640
image = Image.open('./Cards.jpg')
image = image.resize(size=(img_width,img_height))
image_array = np.array(image)
image_array = image_array / 255.0
image_array = np.expand_dims(image_array, axis = 0)

#infer = Model.signatures[]
output = Model(tf.constant(image_array))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/envs/ML/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/function_type_utils.py:442, in bind_function_inputs(args, kwargs, function_type, default_values)
#     441 try:
# --> 442   bound_arguments = function_type.bind_with_defaults(
#     443       args, sanitized_kwargs, default_values
#     444   )
#     445 except Exception as e:
#
# File /opt/anaconda3/envs/ML/lib/python3.11/site-packages/tensorflow/core/function/polymorphism/function_type.py:277, in FunctionType.bind_with_defaults(self, args, kwargs, default_values)
#     276   if constraint:
# --> 277     with_default_args[arg_name] = constraint.cast(
#     278         with_default_args[arg_name],
#     279         trace_type.InternalCastContext(allow_specs=True),
#     280     )
# ...

# %%
Model.predict
